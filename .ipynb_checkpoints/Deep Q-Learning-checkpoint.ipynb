# %% [markdown]
# ### Training Model

# %%
pip install env
# Out:
# Requirement already satisfied: env in d:\anaconda\lib\site-packages (0.1.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)

# %%
pip install RL
# Out:
# Collecting RL
#   Using cached rl-3.1.tar.gz (443 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Building wheels for collected packages: RL
#   Building wheel for RL (PEP 517): started
#   Building wheel for RL (PEP 517): finished with status 'error'
# Failed to build RL
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda\python.exe' 'D:\Anaconda\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\user\AppData\Local\Temp\tmpa8047g3s'
#        cwd: C:\Users\user\AppData\Local\Temp\pip-install-hj0lu3tq\rl_0c529f3e41814034a7ca3c130ac5ae82
#   Complete output (27 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\rl
#   copying rl\testing.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\utils.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_completion.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_history.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_init.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\__init__.py -> build\lib.win-amd64-cpython-39\rl
#   creating build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\display_matches_hook.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\email.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\factory.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\filename.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\pre_input_hook.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\raw_input.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\static.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\__init__.py -> build\lib.win-amd64-cpython-39\rl\examples
#   running build_ext
#   WARNING: Failed to detect a termcap library; falling back to ncurses
#   A subdirectory or file build already exists.
#   Error occurred while processing: build.
#   building 'rl.readline' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for RL
# ERROR: Could not build wheels for RL which use PEP 517 and cannot be installed directly
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)

# %%
pip install fog
# Out:
# Collecting fog
#   Using cached fog-0.11.8.tar.gz (86 kB)
# Requirement already satisfied: dill>=0.2.7.1 in d:\anaconda\lib\site-packages (from fog) (0.3.4)
# Requirement already satisfied: ebbe<2,>=1.3.1 in d:\anaconda\lib\site-packages (from fog) (1.10.0)
# Requirement already satisfied: emoji<2,>=1 in d:\anaconda\lib\site-packages (from fog) (1.7.0)
# Requirement already satisfied: networkx>=2 in d:\anaconda\lib\site-packages (from fog) (2.7.1)
# Requirement already satisfied: phylactery>=0.1.1 in d:\anaconda\lib\site-packages (from fog) (0.2.3)
# Requirement already satisfied: Unidecode>=1.0.22 in d:\anaconda\lib\site-packages (from fog) (1.2.0)
# Building wheels for collected packages: fog
#   Building wheel for fog (setup.py): started
#   Building wheel for fog (setup.py): finished with status 'error'
#   Running setup.py clean for fog
# Failed to build fog
# Installing collected packages: fog
#     Running setup.py install for fog: started
#     Running setup.py install for fog: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\user\AppData\Local\Temp\pip-wheel-vtppxffi'
#        cwd: C:\Users\user\AppData\Local\Temp\pip-install-gvyirzys\fog_d07d839f50c6414b82777e8533a54389\
#   Complete output (82 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\cfog
#   copying cfog\__init__.py -> build\lib.win-amd64-3.9\cfog
#   creating build\lib.win-amd64-3.9\fog
#   copying fog\utils.py -> build\lib.win-amd64-3.9\fog
#   copying fog\__init__.py -> build\lib.win-amd64-3.9\fog
#   creating build\lib.win-amd64-3.9\cfog\metrics
#   copying cfog\metrics\__init__.py -> build\lib.win-amd64-3.9\cfog\metrics
#   creating build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\cluster.py -> build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\split.py -> build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\transform.py -> build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\utils.py -> build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\__init__.py -> build\lib.win-amd64-3.9\fog\cli
#   copying fog\cli\__main__.py -> build\lib.win-amd64-3.9\fog\cli
#   creating build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\blocking.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\fagin.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\intersection_index.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\key_collision.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\laesa.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\minhash.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\nn_descent.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\pairwise.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\passjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\ppjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\quickjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\sorted_neighborhood.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\utils.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\vp_tree.py -> build\lib.win-amd64-3.9\fog\clustering
#   copying fog\clustering\__init__.py -> build\lib.win-amd64-3.9\fog\clustering
#   creating build\lib.win-amd64-3.9\fog\evaluation
#   copying fog\evaluation\best_matching.py -> build\lib.win-amd64-3.9\fog\evaluation
#   copying fog\evaluation\utils.py -> build\lib.win-amd64-3.9\fog\evaluation
#   copying fog\evaluation\__init__.py -> build\lib.win-amd64-3.9\fog\evaluation
#   creating build\lib.win-amd64-3.9\fog\graph
#   copying fog\graph\projection.py -> build\lib.win-amd64-3.9\fog\graph
#   copying fog\graph\sparsification.py -> build\lib.win-amd64-3.9\fog\graph
#   copying fog\graph\utils.py -> build\lib.win-amd64-3.9\fog\graph
#   copying fog\graph\__init__.py -> build\lib.win-amd64-3.9\fog\graph
#   creating build\lib.win-amd64-3.9\fog\join
#   copying fog\join\hashjoin.py -> build\lib.win-amd64-3.9\fog\join
#   copying fog\join\__init__.py -> build\lib.win-amd64-3.9\fog\join
#   creating build\lib.win-amd64-3.9\fog\key
#   copying fog\key\fingerprint.py -> build\lib.win-amd64-3.9\fog\key
#   copying fog\key\levenshtein.py -> build\lib.win-amd64-3.9\fog\key
#   copying fog\key\misc.py -> build\lib.win-amd64-3.9\fog\key
#   copying fog\key\omission.py -> build\lib.win-amd64-3.9\fog\key
#   copying fog\key\skeleton.py -> build\lib.win-amd64-3.9\fog\key
#   copying fog\key\__init__.py -> build\lib.win-amd64-3.9\fog\key
#   creating build\lib.win-amd64-3.9\fog\lsh
#   copying fog\lsh\minhash.py -> build\lib.win-amd64-3.9\fog\lsh
#   copying fog\lsh\simhash.py -> build\lib.win-amd64-3.9\fog\lsh
#   copying fog\lsh\utils.py -> build\lib.win-amd64-3.9\fog\lsh
#   copying fog\lsh\__init__.py -> build\lib.win-amd64-3.9\fog\lsh
#   creating build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\cosine.py -> build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\dice.py -> build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\jaccard.py -> build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\overlap.py -> build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\utils.py -> build\lib.win-amd64-3.9\fog\metrics
#   copying fog\metrics\__init__.py -> build\lib.win-amd64-3.9\fog\metrics
#   creating build\lib.win-amd64-3.9\fog\phonetics
#   copying fog\phonetics\cologne.py -> build\lib.win-amd64-3.9\fog\phonetics
#   copying fog\phonetics\rusalka.py -> build\lib.win-amd64-3.9\fog\phonetics
#   copying fog\phonetics\__init__.py -> build\lib.win-amd64-3.9\fog\phonetics
#   creating build\lib.win-amd64-3.9\fog\tokenizers
#   copying fog\tokenizers\fingerprint.py -> build\lib.win-amd64-3.9\fog\tokenizers
#   copying fog\tokenizers\ngrams.py -> build\lib.win-amd64-3.9\fog\tokenizers
#   copying fog\tokenizers\words.py -> build\lib.win-amd64-3.9\fog\tokenizers
#   copying fog\tokenizers\__init__.py -> build\lib.win-amd64-3.9\fog\tokenizers
#   creating build\lib.win-amd64-3.9\fog\cli\reporting
#   copying fog\cli\reporting\html.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#   copying fog\cli\reporting\toml.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#   copying fog\cli\reporting\__init__.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#   running build_ext
#   building 'cfog.metrics.levenshtein' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fog
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\user\AppData\Local\Temp\pip-record-gr_60rro\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda\Include\fog'
#          cwd: C:\Users\user\AppData\Local\Temp\pip-install-gvyirzys\fog_d07d839f50c6414b82777e8533a54389\
#     Complete output (84 lines):
#     running install
#     D:\Anaconda\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.9
#     creating build\lib.win-amd64-3.9\cfog
#     copying cfog\__init__.py -> build\lib.win-amd64-3.9\cfog
#     creating build\lib.win-amd64-3.9\fog
#     copying fog\utils.py -> build\lib.win-amd64-3.9\fog
#     copying fog\__init__.py -> build\lib.win-amd64-3.9\fog
#     creating build\lib.win-amd64-3.9\cfog\metrics
#     copying cfog\metrics\__init__.py -> build\lib.win-amd64-3.9\cfog\metrics
#     creating build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\cluster.py -> build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\split.py -> build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\transform.py -> build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\utils.py -> build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\__init__.py -> build\lib.win-amd64-3.9\fog\cli
#     copying fog\cli\__main__.py -> build\lib.win-amd64-3.9\fog\cli
#     creating build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\blocking.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\fagin.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\intersection_index.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\key_collision.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\laesa.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\minhash.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\nn_descent.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\pairwise.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\passjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\ppjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\quickjoin.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\sorted_neighborhood.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\utils.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\vp_tree.py -> build\lib.win-amd64-3.9\fog\clustering
#     copying fog\clustering\__init__.py -> build\lib.win-amd64-3.9\fog\clustering
#     creating build\lib.win-amd64-3.9\fog\evaluation
#     copying fog\evaluation\best_matching.py -> build\lib.win-amd64-3.9\fog\evaluation
#     copying fog\evaluation\utils.py -> build\lib.win-amd64-3.9\fog\evaluation
#     copying fog\evaluation\__init__.py -> build\lib.win-amd64-3.9\fog\evaluation
#     creating build\lib.win-amd64-3.9\fog\graph
#     copying fog\graph\projection.py -> build\lib.win-amd64-3.9\fog\graph
#     copying fog\graph\sparsification.py -> build\lib.win-amd64-3.9\fog\graph
#     copying fog\graph\utils.py -> build\lib.win-amd64-3.9\fog\graph
#     copying fog\graph\__init__.py -> build\lib.win-amd64-3.9\fog\graph
#     creating build\lib.win-amd64-3.9\fog\join
#     copying fog\join\hashjoin.py -> build\lib.win-amd64-3.9\fog\join
#     copying fog\join\__init__.py -> build\lib.win-amd64-3.9\fog\join
#     creating build\lib.win-amd64-3.9\fog\key
#     copying fog\key\fingerprint.py -> build\lib.win-amd64-3.9\fog\key
#     copying fog\key\levenshtein.py -> build\lib.win-amd64-3.9\fog\key
#     copying fog\key\misc.py -> build\lib.win-amd64-3.9\fog\key
#     copying fog\key\omission.py -> build\lib.win-amd64-3.9\fog\key
#     copying fog\key\skeleton.py -> build\lib.win-amd64-3.9\fog\key
#     copying fog\key\__init__.py -> build\lib.win-amd64-3.9\fog\key
#     creating build\lib.win-amd64-3.9\fog\lsh
#     copying fog\lsh\minhash.py -> build\lib.win-amd64-3.9\fog\lsh
#     copying fog\lsh\simhash.py -> build\lib.win-amd64-3.9\fog\lsh
#     copying fog\lsh\utils.py -> build\lib.win-amd64-3.9\fog\lsh
#     copying fog\lsh\__init__.py -> build\lib.win-amd64-3.9\fog\lsh
#     creating build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\cosine.py -> build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\dice.py -> build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\jaccard.py -> build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\overlap.py -> build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\utils.py -> build\lib.win-amd64-3.9\fog\metrics
#     copying fog\metrics\__init__.py -> build\lib.win-amd64-3.9\fog\metrics
#     creating build\lib.win-amd64-3.9\fog\phonetics
#     copying fog\phonetics\cologne.py -> build\lib.win-amd64-3.9\fog\phonetics
#     copying fog\phonetics\rusalka.py -> build\lib.win-amd64-3.9\fog\phonetics
#     copying fog\phonetics\__init__.py -> build\lib.win-amd64-3.9\fog\phonetics
#     creating build\lib.win-amd64-3.9\fog\tokenizers
#     copying fog\tokenizers\fingerprint.py -> build\lib.win-amd64-3.9\fog\tokenizers
#     copying fog\tokenizers\ngrams.py -> build\lib.win-amd64-3.9\fog\tokenizers
#     copying fog\tokenizers\words.py -> build\lib.win-amd64-3.9\fog\tokenizers
#     copying fog\tokenizers\__init__.py -> build\lib.win-amd64-3.9\fog\tokenizers
#     creating build\lib.win-amd64-3.9\fog\cli\reporting
#     copying fog\cli\reporting\html.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#     copying fog\cli\reporting\toml.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#     copying fog\cli\reporting\__init__.py -> build\lib.win-amd64-3.9\fog\cli\reporting
#     running build_ext
#     building 'cfog.metrics.levenshtein' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'D:\Anaconda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gvyirzys\\fog_d07d839f50c6414b82777e8533a54389\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\user\AppData\Local\Temp\pip-record-gr_60rro\install-record.txt' --single-version-externally-managed --compile --install-headers 'D:\Anaconda\Include\fog' Check the logs for full command output.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)

# %%
pip install urlparse4
# Out:
# Collecting urlparse4
#   Using cached urlparse4-0.1.3.tar.gz (158 kB)
#   Using cached urlparse4-0.1.2.tar.gz (158 kB)
#   Using cached urlparse4-0.1.1.tar.gz (154 kB)
#   Using cached urlparse4-0.1.tar.gz (152 kB)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_d760846d008c4e96856f7f40e403f504\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_d760846d008c4e96856f7f40e403f504\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\user\AppData\Local\Temp\pip-pip-egg-info-_gfag08t'
#          cwd: C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_d760846d008c4e96856f7f40e403f504\
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_d760846d008c4e96856f7f40e403f504\setup.py", line 46
#         print "urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again."
#               ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again.")?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/af/6f/a2d1a397b47ce3af6c5bb8936a7a8f930bf29b4df42081da842c5c84c1d1/urlparse4-0.1.3.tar.gz#sha256=ac0e9869b96a162ceeb175200d4c2f947c42991cfc2d53b8030748facbf8f791 (from https://pypi.org/simple/urlparse4/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_65a857f3ac80413aa5de07889adb22c9\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_65a857f3ac80413aa5de07889adb22c9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\user\AppData\Local\Temp\pip-pip-egg-info-d2ivoie6'
#          cwd: C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_65a857f3ac80413aa5de07889adb22c9\
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_65a857f3ac80413aa5de07889adb22c9\setup.py", line 46
#         print "urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again."
#               ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again.")?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d4/a9/1a1408217d91d726d7f91d62dae3e33f5728fa07cef51b6d584002c96c80/urlparse4-0.1.2.tar.gz#sha256=048cc4519a49c0bb35ee81636d1f0e0fe2207e3bc1723a6398557fb613092bbd (from https://pypi.org/simple/urlparse4/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_6780c41dfef547c0a78e7fb6acaf2759\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_6780c41dfef547c0a78e7fb6acaf2759\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\user\AppData\Local\Temp\pip-pip-egg-info-7oj3sifw'
#          cwd: C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_6780c41dfef547c0a78e7fb6acaf2759\
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_6780c41dfef547c0a78e7fb6acaf2759\setup.py", line 46
#         print "urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again."
#               ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again.")?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/90/c1/caaff08824a5237d4d85bf569565049729aa497f1c6c2e4da7e873b82783/urlparse4-0.1.1.tar.gz#sha256=cc69218746b5cfda3543080e5b9dc1e93307222ab343ce729493c3ed292da207 (from https://pypi.org/simple/urlparse4/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_a81442a4d755493d920a698964b8c702\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-y87u2492\\urlparse4_a81442a4d755493d920a698964b8c702\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\user\AppData\Local\Temp\pip-pip-egg-info-v6z4dlmr'
#          cwd: C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_a81442a4d755493d920a698964b8c702\
#     Complete output (6 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\user\AppData\Local\Temp\pip-install-y87u2492\urlparse4_a81442a4d755493d920a698964b8c702\setup.py", line 46
#         print "urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again."
#               ^
#     SyntaxError: Missing parentheses in call to 'print'. Did you mean print("urlparse4/gurl.cpp not found and Cython failed to run to recreate it. Please install/upgrade Cython and try again.")?
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/36/86/c8fa7c9534d1560f38455154bfc4000fb2cc02f60241f3e0e99582134aef/urlparse4-0.1.tar.gz#sha256=118b336f5c56e8419c20507710aaaf264aad17d46dd54e580e447f653e401f91 (from https://pypi.org/simple/urlparse4/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement urlparse4 (from versions: 0.1, 0.1.1, 0.1.2, 0.1.3)
# ERROR: No matching distribution found for urlparse4
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)

# %%
pip install rl
# Out:
# Collecting rl
#   Using cached rl-3.1.tar.gz (443 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Building wheels for collected packages: rl
#   Building wheel for rl (PEP 517): started
#   Building wheel for rl (PEP 517): finished with status 'error'
# Failed to build rl
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
#    command: 'D:\Anaconda\python.exe' 'D:\Anaconda\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\user\AppData\Local\Temp\tmpu0tzrjhh'
#        cwd: C:\Users\user\AppData\Local\Temp\pip-install-n5aitvye\rl_f224d8ffc5c54768abd373762fe5c530
#   Complete output (27 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\rl
#   copying rl\testing.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\utils.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_completion.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_history.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\_init.py -> build\lib.win-amd64-cpython-39\rl
#   copying rl\__init__.py -> build\lib.win-amd64-cpython-39\rl
#   creating build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\display_matches_hook.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\email.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\factory.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\filename.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\pre_input_hook.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\raw_input.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\static.py -> build\lib.win-amd64-cpython-39\rl\examples
#   copying rl\examples\__init__.py -> build\lib.win-amd64-cpython-39\rl\examples
#   running build_ext
#   WARNING: Failed to detect a termcap library; falling back to ncurses
#   A subdirectory or file build already exists.
#   Error occurred while processing: build.
#   building 'rl.readline' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for rl
# ERROR: Could not build wheels for rl which use PEP 517 and cannot be installed directly
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\anaconda\lib\site-packages)

# %%
import
from env import Offload
from RL_brain import DeepQNetwork
import numpy as np
import random
import matplotlib.pyplot as plt
np.set_printoptions(threshold=np.inf)


def random_pick(some_list, probabilities):
    x = random.uniform(0, 1)
    cumulative_probability = 0.0
    for item, item_probability in zip(some_list, probabilities):
        cumulative_probability += item_probability
        if x < cumulative_probability:
            break
    return item


def reward_fun(delay, max_delay, unfinish_indi):

    # still use reward, but use the negative value
    penalty = - max_delay * 2

    if unfinish_indi:
        reward = penalty
    else:
        reward = - delay

    return reward


def train(iot_RL_list, NUM_EPISODE):

    RL_step = 0

    for episode in range(NUM_EPISODE):

        print(episode)
        print(iot_RL_list[0].epsilon)
        # BITRATE ARRIVAL
        bitarrive = np.random.uniform(env.min_bit_arrive, env.max_bit_arrive, size=[env.n_time, env.n_iot])
        task_prob = env.task_arrive_prob
        bitarrive = bitarrive * (np.random.uniform(0, 1, size=[env.n_time, env.n_iot]) < task_prob)
        bitarrive[-env.max_delay:, :] = np.zeros([env.max_delay, env.n_iot])

        # =================================================================================================
        # ========================================= DRL ===================================================
        # =================================================================================================

        # OBSERVATION MATRIX SETTING
        history = list()
        for time_index in range(env.n_time):
            history.append(list())
            for iot_index in range(env.n_iot):
                tmp_dict = {'observation': np.zeros(env.n_features),
                            'lstm': np.zeros(env.n_lstm_state),
                            'action': np.nan,
                            'observation_': np.zeros(env.n_features),
                            'lstm_': np.zeros(env.n_lstm_state)}
                history[time_index].append(tmp_dict)
        reward_indicator = np.zeros([env.n_time, env.n_iot])

        # INITIALIZE OBSERVATION
        observation_all, lstm_state_all = env.reset(bitarrive)

        # TRAIN DRL
        while True:

            # PERFORM ACTION
            action_all = np.zeros([env.n_iot])
            for iot_index in range(env.n_iot):

                observation = np.squeeze(observation_all[iot_index, :])

                if np.sum(observation) == 0:
                    # if there is no task, action = 0 (also need to be stored)
                    action_all[iot_index] = 0
                else:
                    action_all[iot_index] = iot_RL_list[iot_index].choose_action(observation)

                if observation[0] != 0:
                    iot_RL_list[iot_index].do_store_action(episode, env.time_count, action_all[iot_index])

            # OBSERVE THE NEXT STATE AND PROCESS DELAY (REWARD)
            observation_all_, lstm_state_all_, done = env.step(action_all)

            # should store this information in EACH time slot
            for iot_index in range(env.n_iot):
                iot_RL_list[iot_index].update_lstm(lstm_state_all_[iot_index,:])

            process_delay = env.process_delay
            unfinish_indi = env.process_delay_unfinish_ind

            # STORE MEMORY; STORE TRANSITION IF THE TASK PROCESS DELAY IS JUST UPDATED
            for iot_index in range(env.n_iot):

                history[env.time_count - 1][iot_index]['observation'] = observation_all[iot_index, :]
                history[env.time_count - 1][iot_index]['lstm'] = np.squeeze(lstm_state_all[iot_index, :])
                history[env.time_count - 1][iot_index]['action'] = action_all[iot_index]
                history[env.time_count - 1][iot_index]['observation_'] = observation_all_[iot_index]
                history[env.time_count - 1][iot_index]['lstm_'] = np.squeeze(lstm_state_all_[iot_index,:])

                update_index = np.where((1 - reward_indicator[:,iot_index]) * process_delay[:,iot_index] > 0)[0]

                if len(update_index) != 0:
                    for update_ii in range(len(update_index)):
                        time_index = update_index[update_ii]
                        iot_RL_list[iot_index].store_transition(history[time_index][iot_index]['observation'],
                                                                history[time_index][iot_index]['lstm'],
                                                                history[time_index][iot_index]['action'],
                                                                reward_fun(process_delay[time_index, iot_index],
                                                                           env.max_delay,
                                                                           unfinish_indi[time_index, iot_index]),
                                                                history[time_index][iot_index]['observation_'],
                                                                history[time_index][iot_index]['lstm_'])
                        iot_RL_list[iot_index].do_store_reward(episode, time_index,
                                                               reward_fun(process_delay[time_index, iot_index],
                                                                          env.max_delay,
                                                                          unfinish_indi[time_index, iot_index]))
                        iot_RL_list[iot_index].do_store_delay(episode, time_index,
                                                              process_delay[time_index, iot_index])
                        reward_indicator[time_index, iot_index] = 1

            # ADD STEP (one step does not mean one store)
            RL_step += 1

            # UPDATE OBSERVATION
            observation_all = observation_all_
            lstm_state_all = lstm_state_all_

            # CONTROL LEARNING START TIME AND FREQUENCY
            if (RL_step > 200) and (RL_step % 10 == 0):
                for iot in range(env.n_iot):
                    iot_RL_list[iot].learn()

            # GAME ENDS
            if done:
                break
        #  =================================================================================================
        #  ======================================== DRL END=================================================
        #  =================================================================================================


if __name__ == "__main__":

    NUM_IOT = 50
    NUM_FOG = 3
    NUM_EPISODE = 1000
    NUM_TIME_BASE = 100
    MAX_DELAY = 10
    NUM_TIME = NUM_TIME_BASE + MAX_DELAY

    # GENERATE ENVIRONMENT
    env = Offload(NUM_IOT, NUM_FOG, NUM_TIME, MAX_DELAY)

    # GENERATE MULTIPLE CLASSES FOR RL
    iot_RL_list = list()
    for iot in range(NUM_IOT):
        iot_RL_list.append(DeepQNetwork(env.n_actions, env.n_features, env.n_lstm_state, env.n_time,
                                        learning_rate=0.01,
                                        reward_decay=0.9,
                                        e_greedy=0.99,
                                        replace_target_iter=200,  # each 200 steps, update target net
                                        memory_size=500,  # maximum of memory
                                        ))

    # TRAIN THE SYSTEM
    train(iot_RL_list, NUM_EPISODE)
    print('Training Finished')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 from env import Offload
#       2 from RL_brain import DeepQNetwork
#       3 import numpy as np
#
# ImportError: cannot import name 'Offload' from 'env' (D:\Anaconda\lib\site-packages\env.py)

# %% [markdown]
# This code appears to be an implementation of a deep reinforcement learning algorithm. It's a variation of the Q-Learning algorithm, where the Q-value function is represented by a neural network called the DeepQNetwork.
#
# The train function is the main function to train the model, it takes in two inputs, the iot_RL_list and NUM_EPISODE which are a list of DeepQNetwork objects and the number of episodes to run respectively. The algorithm goes through each episode, and in each episode, it initializes the arrival of bits and the history of observations, actions, and rewards.
#
# In each time step, the algorithm selects actions for each of the env.n_iot agents based on their current observation, which is the state of the environment. The actions are selected by the choose_action function in the DeepQNetwork class, which outputs a continuous value in the range of 0 to 1. The continuous value is then discretized into binary values (0 or 1) representing whether to offload the task or not.
#
# After the actions are selected, the environment takes a step and updates the state of the environment, process delays and the next observation, which are used to calculate the reward for each of the env.n_iot agents. The reward is calculated based on the reward_fun function, which returns a negative value of the process delay.
#
# Finally, the algorithm updates the history of observations, actions, and rewards and continues to the next time step until the episode is completed. The neural network is updated after each episode based on the history of observations, actions, and rewards, using the learn function in the DeepQNetwork class.
